# %%
import requests
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import talib
from datetime import datetime

# %%
start = datetime(2017, 6, 25)
end = datetime(2018, 6, 25)
stock = 'NVDA'
df = web.DataReader(stock, 'iex', start, end)

fig, ax = plt.subplots(figsize=(15,10))
ema10 = talib.EMA(df.close, timeperiod=10)
ema75 = talib.EMA(df.close, timeperiod=75)
dates_list = [datetime.strptime(date, '%Y-%m-%d').date() for date in df.index]

delta = (dates_list[len(dates_list)-1] - dates_list[0])

df['ema10'] = ema10
df['ema75'] = ema75

ax.plot(dates_list, df.close, label=stock)
ax.plot(dates_list, ema10, label='EMA 10')
ax.plot(dates_list, ema75, label='EMA 75')

ax.set_xlabel('Date')
ax.set_ylabel('Closing price ($)')
ax.legend()

plt.grid(True)
plt.show()

# print(df.close[len(df)-5:])
# print(talib.EMA(df.close, timeperiod=10)[len(df)-5:])
# Out:
# 1y

# %%
fig, ax = plt.subplots(figsize=(15,5))
macd, macdsignal, macdhist = talib.MACD(df.close, fastperiod=12, slowperiod=26, signalperiod=9)
rsi = talib.SI(df.close, timeperiod=14)
dates_list = [datetime.strptime(date, '%Y-%m-%d').date() for date in df.index]

ax.plot(dates_list, rsi, label='MACD SIGNAL')

df['macd'] = macd
df['macdsignal'] = macdsignal
df['macdhist'] = macdhist
df['rsi'] = rsi

ax.set_xlabel('Date')
ax.set_ylabel('MACD')
ax.legend()

plt.grid(True)
plt.show()

# %%
df.tail(15)
# Out:
#                open      high       low   close    volume       ema10  \
# date
# 2018-06-04  259.000  265.7400  257.7000  264.85  16050641  253.092978
# 2018-06-05  264.980  266.5900  263.1700  265.07   9792801  255.270618
# 2018-06-06  261.430  265.2800  260.7700  265.15   9283856  257.066870
# 2018-06-07  265.000  265.4785  259.2500  262.90   9236216  258.127439
# 2018-06-08  259.960  264.0000  259.2000  262.28   9011443  258.882450
# 2018-06-11  261.770  263.4500  260.1000  260.62   6634253  259.198368
# 2018-06-12  261.690  263.0700  259.6600  262.58   7978985  259.813210
# 2018-06-13  262.640  265.6700  262.0310  262.40   8455159  260.283536
# 2018-06-14  264.220  269.2000  263.6200  266.91  10750411  261.488347
# 2018-06-15  264.600  267.4800  263.3484  265.26  10806488  262.174102
# 2018-06-18  263.480  265.8000  262.3800  265.09   8906674  262.704266
# 2018-06-19  260.920  263.6400  255.0200  260.17  14873324  262.243490
# 2018-06-20  261.832  264.4500  260.2808  262.31   9244494  262.255583
# 2018-06-21  263.600  264.3400  256.8000  257.11   8987906  261.320022
# 2018-06-22  257.950  258.4900  250.3301  250.95  10853954  259.434564
#
#                  ema75      macd  macdsignal  macdhist
# date
# 2018-06-04  239.615864  5.346879    4.380072  0.966807
# 2018-06-05  240.285709  5.987641    4.701586  1.286055
# 2018-06-06  240.940033  6.427810    5.046831  1.380979
# 2018-06-07  241.517927  6.519932    5.341451  1.178481
# 2018-06-08  242.064297  6.468348    5.566830  0.901518
# 2018-06-11  242.552605  6.221798    5.697824  0.523974
# 2018-06-12  243.079642  6.114082    5.781076  0.333007
# 2018-06-13  243.588072  5.945654    5.813991  0.131663
# 2018-06-14  244.201807  6.105710    5.872335  0.233375
# 2018-06-15  244.755970  6.029905    5.903849  0.126056
# 2018-06-18  245.291076  5.888236    5.900727 -0.012491
# 2018-06-19  245.682627  5.317660    5.784113 -0.466453
# 2018-06-20  246.120189  4.980741    5.623439 -0.642698
# 2018-06-21  246.409395  4.245197    5.347790 -1.102594
# 2018-06-22  246.528884  3.129141    4.904061 -1.774919
